# %%
import tensorflow as tf
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.models import HoverTool
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input,Dense, Subtract, Add, Concatenate
from tensorflow.keras.optimizers import Adam

real_dem = pd.read_excel('C:/Users/ERIC/Desktop/Forecast Real Demand/Demanda Real Balance_0_v3 Dia Operacion 2020-03-09 v2020 03 23_12 25 01.xlsm',0)
real_dem_daybef = pd.read_excel('C:/Users/ERIC/Desktop/Forecast Real Demand/Demanda Real Balance_0_v3 Dia Operacion 2020-03-09 v2020 03 23_12 25 01.xlsm',1)
forec_dem = pd.read_excel('C:/Users/ERIC/Desktop/Forecast Real Demand/Demanda Real Balance_0_v3 Dia Operacion 2020-03-09 v2020 03 23_12 25 01.xlsm',2)
# Dataframes
real_dem = pd.DataFrame(real_dem)
real_dem_daybef = pd.DataFrame(real_dem_daybef)
forec_dem = pd.DataFrame(forec_dem)
#Data from the day before
cen_x_train_daybef = real_dem_daybef.iloc[:20,7:8]
cen_x_train_daybef = pd.DataFrame(cen_x_train_daybef)

#Data from the forecast
cen_x_train_forec = forec_dem.iloc[:20,3:4]
cen_x_train_forec = pd.DataFrame(cen_x_train_forec)

# Training dataset
cen_x_train = real_dem.iloc[0:20, 3:7].values
cen_x_train = pd.DataFrame(cen_x_train)

cen_y_train = real_dem.iloc[0:20, 7:8].values
cen_y_train = pd.DataFrame(cen_y_train)


# Test dataset
cen_x_test = real_dem.iloc[20:24, 3:7].values
cen_x_test = pd.DataFrame(cen_x_test)

cen_y_test = real_dem.iloc[20:24, 7:8].values
cen_y_test = pd.DataFrame(cen_y_test)

# Input from the current day
input_tensor1 = Input(shape=(1,))
input_tensor2 = Input(shape=(1,))
input_tensor3 = Input(shape=(1,))
input_tensor4 = Input(shape=(1,))
# Input from the current day
input_tensor5 = Input(shape=(1,))
# Input from the forecast
input_tensor6 = Input(shape=(1,))

merge_layer = Add()([input_tensor1, input_tensor2])
merge_layer1 = Add()([merge_layer, input_tensor4])
merge_layer2 = Subtract()([merge_layer1, input_tensor3])

hidden_layer = Dense(500, activation = 'relu')(merge_layer2)

out_tensor = Concatenate()([hidden_layer, input_tensor5, input_tensor6])
hidden_layer2 = Dense(500, activation = 'relu')(out_tensor)

output_tensor = Dense(24)(hidden_layer)

model = Model([input_tensor1,input_tensor2,input_tensor3,input_tensor4, input_tensor5,input_tensor6], output_tensor)

model.compile(optimizer= Adam(0.01),  loss='mean_absolute_error', metrics = ['accuracy'])

model.summary()

model.fit([cen_x_train[0],cen_x_train[1],cen_x_train[2],cen_x_train[3],
          cen_x_train_daybef, cen_x_train_forec],
          cen_y_train,
          epochs=20,
          batch_size=2,
          validation_split=0.1,
          verbose=True)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_61 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_62 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 1)            0           input_61[0][0]
#                                                                  input_62[0][0]
# __________________________________________________________________________________________________
# input_64 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 1)            0           add_12[0][0]
#                                                                  input_64[0][0]
# __________________________________________________________________________________________________
# input_63 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 1)            0           add_13[0][0]
#                                                                  input_63[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 500)          1000        subtract_5[0][0]
# __________________________________________________________________________________________________
# input_65 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_66 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 24)           12024       dense_23[0][0]
# ==================================================================================================
# Total params: 13,024
# Trainable params: 13,024
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.series.Series'>", "<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
# Train on 18 samples, validate on 2 samples
# Epoch 1/20
# 18/18 [==============================] - 0s 15ms/sample - loss: 3004.1286 - accuracy: 0.0000e+00 - val_loss: 1581.4851 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 792.2245 - accuracy: 0.0000e+00 - val_loss: 622.3087 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 428.0381 - accuracy: 0.0000e+00 - val_loss: 361.6324 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 253.6823 - accuracy: 0.0000e+00 - val_loss: 241.9565 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 184.1265 - accuracy: 0.0000e+00 - val_loss: 255.8434 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 18/18 [==============================] - ETA: 0s - loss: 205.4736 - accuracy: 0.0000e+ - 0s 2ms/sample - loss: 166.7253 - accuracy: 0.0000e+00 - val_loss: 209.4615 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 129.3690 - accuracy: 0.1111 - val_loss: 202.8010 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 138.3321 - accuracy: 0.0000e+00 - val_loss: 114.6484 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 122.0492 - accuracy: 0.0000e+00 - val_loss: 194.7873 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 126.8851 - accuracy: 0.0000e+00 - val_loss: 159.0762 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 133.6370 - accuracy: 0.0000e+00 - val_loss: 128.7208 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 123.3442 - accuracy: 0.0000e+00 - val_loss: 156.3186 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 137.1527 - accuracy: 0.0000e+00 - val_loss: 174.1643 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 112.1966 - accuracy: 0.0000e+00 - val_loss: 126.6663 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 18/18 [==============================] - 0s 1ms/sample - loss: 109.2551 - accuracy: 0.2222 - val_loss: 141.6779 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 18/18 [==============================] - 0s 1ms/sample - loss: 125.7208 - accuracy: 0.0000e+00 - val_loss: 163.9761 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 119.6314 - accuracy: 0.0000e+00 - val_loss: 165.1266 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 139.7491 - accuracy: 0.5556 - val_loss: 128.8170 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 18/18 [==============================] - 0s 2ms/sample - loss: 107.3300 - accuracy: 0.0000e+00 - val_loss: 152.7282 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 18/18 [==============================] - 0s 3ms/sample - loss: 106.2055 - accuracy: 0.0000e+00 - val_loss: 157.4595 - val_accuracy: 0.0000e+00
